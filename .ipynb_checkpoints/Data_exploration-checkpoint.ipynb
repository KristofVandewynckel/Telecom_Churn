# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset.csv')
pd.set_option('display.max_columns', None)
df.columns = df.columns.str.lower()
df.head(50)
# Out:
#     customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
for idx, row in df.iterrows():
    if df.loc[idx,'phoneservice'] == 'No':
        df.loc[idx,'multiplelines'] = 'No'
    if df.loc[idx,'internetservice'] == 'No':
        df.loc[idx,['onlinesecurity','onlinebackup','deviceprotection','techsupport','streamingtv','streamingmovies']] = 'No'

# %%
# Iterating through all the columns to understand the contents of the data
for each in df.columns:
    print(f"Number of {each}: {df[each].nunique()}")
    print(f"Options of {each}: {df[each].unique()}")
    print(f"Value counts: {df[each].value_counts()}")
    print()
# Out:
# Number of customerid: 7043
# Options of customerid: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# Value counts: 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: customerid, Length: 7043, dtype: int64
#
# Number of gender: 2
# Options of gender: ['Female' 'Male']
# Value counts: Male      3555
# Female    3488
# Name: gender, dtype: int64
#
# Number of seniorcitizen: 2
# Options of seniorcitizen: [0 1]
# Value counts: 0    5901
# 1    1142
# Name: seniorcitizen, dtype: int64
#
# Number of partner: 2
# Options of partner: ['Yes' 'No']
# Value counts: No     3641
# Yes    3402
# Name: partner, dtype: int64
#
# Number of dependents: 2
# Options of dependents: ['No' 'Yes']
# Value counts: No     4933
# Yes    2110
# Name: dependents, dtype: int64
#
# Number of tenure: 73
# ...

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
check = df[df['tenure']== 1]
check = check[check['churn']=='Yes']
check
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 22    1066-JKSGK    Male              0      No         No       1
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 80    5919-TMRGD  Female              0      No        Yes       1
# 133   3091-FYHKI    Male              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 6943  0032-PGELS  Female              0     Yes        Yes       1
# 6969  4745-LSPLO    Male              0      No         No       1
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7032  6894-LFHLY    Male              1      No         No       1
#
#      phoneservice     multiplelines internetservice       onlinesecurity  \
# 20             No  No phone service             DSL                   No
# ...

# %%
df["totalcharges"].fillna(0, inplace = True)

# %%
columns=[]
for i in df.columns:
    if len(df[i].unique()) <= 2:
        columns.append(i)
columns
# Out:
# ['gender',
#  'seniorcitizen',
#  'partner',
#  'dependents',
#  'phoneservice',
#  'multiplelines',
#  'onlinesecurity',
#  'onlinebackup',
#  'deviceprotection',
#  'techsupport',
#  'streamingtv',
#  'streamingmovies',
#  'paperlessbilling',
#  'churn']

# %%
dumdum=pd.get_dummies(df,columns=columns,drop_first=True)
dumdum = pd.get_dummies(dumdum, columns = ['internetservice','contract','paymentmethod'])
dumdum.rename(columns= {'seniorcitizen_1':'seniorcitizen_Yes'}, inplace= True)
dumdum.head(20)
# Out:
#     customerid  tenure  monthlycharges  totalcharges  gender_Male  \
# 0   7590-VHVEG       1           29.85         29.85            0
# 1   5575-GNVDE      34           56.95       1889.50            1
# 2   3668-QPYBK       2           53.85        108.15            1
# 3   7795-CFOCW      45           42.30       1840.75            1
# 4   9237-HQITU       2           70.70        151.65            0
# 5   9305-CDSKC       8           99.65        820.50            0
# 6   1452-KIOVK      22           89.10       1949.40            1
# 7   6713-OKOMC      10           29.75        301.90            0
# 8   7892-POOKP      28          104.80       3046.05            0
# 9   6388-TABGU      62           56.15       3487.95            1
# 10  9763-GRSKD      13           49.95        587.45            1
# 11  7469-LKBCI      16           18.95        326.80            1
# 12  8091-TTVAX      58          100.35       5681.10            1
# ...

# %%
dumdum.to_csv('Dummy_data.csv', index=False)
